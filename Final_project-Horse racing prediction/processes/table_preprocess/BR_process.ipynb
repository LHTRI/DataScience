# %% [markdown]
# ## Lấy dữ liệu tại bảng BR

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Get data path

# %%
import os.path as path
data_path =  path.abspath(path.join('' ,"../../data/historical_data"))
data_path = data_path + '\\BR.pickle.gz'
data_path
# Out:
# 'D:\\Funix_FPT\\DataScience\\Final_Project\\horse_race_project\\data\\historical_data\\BR.pickle.gz'

# %%
BR_df = pd.read_pickle(data_path)
BR_df
# Out:
#                               filename  line_no head$RecordSpec  \
# 0      BRFW2018090320180903133011.json        1              BR
# 1      BRFW2018090320180903133011.json        2              BR
# 2      BRFW2018090320180903133011.json        3              BR
# 3      BRFW2018090320180903133011.json        4              BR
# 4      BRFW2018090320180903133011.json        5              BR
# ...                                ...      ...             ...
# 17037  BRFW2018053120180531190115.json        2              BR
# 17038  BRFW2018053120180531190115.json        3              BR
# 17039  BRFW2018053120180531190115.json        4              BR
# 17040  BRFW2018053120180531190115.json        5              BR
# 17041  BRFW2018053120180531190115.json        6              BR
#
#        head$DataKubun  head$MakeDate$Year  head$MakeDate$Month  \
# 0                   2                2018                    9
# 1                   2                2018                    9
# ...

# %%
BR_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17042 entries, 0 to 17041
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   filename                    17042 non-null  object
#  1   line_no                     17042 non-null  int64
#  2   head$RecordSpec             17042 non-null  object
#  3   head$DataKubun              17042 non-null  int64
#  4   head$MakeDate$Year          17042 non-null  int64
#  5   head$MakeDate$Month         17042 non-null  int64
#  6   head$MakeDate$Day           17042 non-null  int64
#  7   BreederCode                 17042 non-null  int64
#  8   BreederName_Co              17042 non-null  object
#  9   BreederName                 17042 non-null  object
#  10  BreederNameKana             17042 non-null  object
#  11  BreederNameEng              17042 non-null  object
#  12  Address                     17042 non-null  object
# ...

# %%
for c in BR_df.columns:
    print(c)
# Out:
# filename
# line_no
# head$RecordSpec
# head$DataKubun
# head$MakeDate$Year
# head$MakeDate$Month
# head$MakeDate$Day
# BreederCode
# BreederName_Co
# BreederName
# BreederNameKana
# BreederNameEng
# Address
# HonRuikei$1$SetYear
# HonRuikei$1$HonSyokinTotal
# HonRuikei$1$FukaSyokin
# HonRuikei$1$ChakuKaisu$1
# HonRuikei$1$ChakuKaisu$2
# HonRuikei$1$ChakuKaisu$3
# HonRuikei$1$ChakuKaisu$4
# HonRuikei$1$ChakuKaisu$5
# HonRuikei$1$ChakuKaisu$6
# HonRuikei$2$SetYear
# HonRuikei$2$HonSyokinTotal
# HonRuikei$2$FukaSyokin
# HonRuikei$2$ChakuKaisu$1
# HonRuikei$2$ChakuKaisu$2
# HonRuikei$2$ChakuKaisu$3
# HonRuikei$2$ChakuKaisu$4
# HonRuikei$2$ChakuKaisu$5
# HonRuikei$2$ChakuKaisu$6
# crlf

# %%
BR_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17042 entries, 0 to 17041
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   filename                    17042 non-null  object
#  1   line_no                     17042 non-null  int64
#  2   head$RecordSpec             17042 non-null  object
#  3   head$DataKubun              17042 non-null  int64
#  4   head$MakeDate$Year          17042 non-null  int64
#  5   head$MakeDate$Month         17042 non-null  int64
#  6   head$MakeDate$Day           17042 non-null  int64
#  7   BreederCode                 17042 non-null  int64
#  8   BreederName_Co              17042 non-null  object
#  9   BreederName                 17042 non-null  object
#  10  BreederNameKana             17042 non-null  object
#  11  BreederNameEng              17042 non-null  object
#  12  Address                     17042 non-null  object
# ...
