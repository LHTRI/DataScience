# %% [markdown]
# ## Lấy dữ liệu tại bảng BN

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Get data path

# %%
import os.path as path
data_path =  path.abspath(path.join('' ,"../../data/historical_data"))
data_path = data_path + '\\BN.pickle.gz'
data_path
# Out:
# 'D:\\Funix_FPT\\DataScience\\Final_Project\\horse_race_project\\data\\historical_data\\BN.pickle.gz'

# %%
BN_df = pd.read_pickle(data_path)
BN_df
# Out:
#                              filename  line_no head$RecordSpec  \
# 0     BNFW2018051420180514133247.json        1              BN
# 1     BNFW2018051420180514133247.json        2              BN
# 2     BNFW2018051420180514133247.json        3              BN
# 3     BNFW2018051420180514133247.json        4              BN
# 4     BNFW2018051420180514133247.json        5              BN
# ...                               ...      ...             ...
# 8992  BNFW2018052120180521133118.json      470              BN
# 8993  BNFW2018052120180521133118.json      471              BN
# 8994  BNFW2018052120180521133118.json      472              BN
# 8995  BNFW2018052120180521133118.json      473              BN
# 8996  BNFW2018052120180521133118.json      474              BN
#
#       head$DataKubun  head$MakeDate$Year  head$MakeDate$Month  \
# 0                  2                2018                    5
# 1                  2                2018                    5
# ...

# %%
BN_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8997 entries, 0 to 8996
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   filename                    8997 non-null   object
#  1   line_no                     8997 non-null   int64
#  2   head$RecordSpec             8997 non-null   object
#  3   head$DataKubun              8997 non-null   int64
#  4   head$MakeDate$Year          8997 non-null   int64
#  5   head$MakeDate$Month         8997 non-null   int64
#  6   head$MakeDate$Day           8997 non-null   int64
#  7   BanusiCode                  8997 non-null   int64
#  8   BanusiName_Co               8997 non-null   object
#  9   BanusiName                  8997 non-null   object
#  10  BanusiNameKana              8997 non-null   object
#  11  BanusiNameEng               8997 non-null   object
#  12  Fukusyoku                   8997 non-null   object
# ...

# %%
for c in BN_df.columns:
    print(c)
# Out:
# filename
# line_no
# head$RecordSpec
# head$DataKubun
# head$MakeDate$Year
# head$MakeDate$Month
# head$MakeDate$Day
# BanusiCode
# BanusiName_Co
# BanusiName
# BanusiNameKana
# BanusiNameEng
# Fukusyoku
# HonRuikei$1$SetYear
# HonRuikei$1$HonSyokinTotal
# HonRuikei$1$FukaSyokin
# HonRuikei$1$ChakuKaisu$1
# HonRuikei$1$ChakuKaisu$2
# HonRuikei$1$ChakuKaisu$3
# HonRuikei$1$ChakuKaisu$4
# HonRuikei$1$ChakuKaisu$5
# HonRuikei$1$ChakuKaisu$6
# HonRuikei$2$SetYear
# HonRuikei$2$HonSyokinTotal
# HonRuikei$2$FukaSyokin
# HonRuikei$2$ChakuKaisu$1
# HonRuikei$2$ChakuKaisu$2
# HonRuikei$2$ChakuKaisu$3
# HonRuikei$2$ChakuKaisu$4
# HonRuikei$2$ChakuKaisu$5
# HonRuikei$2$ChakuKaisu$6
# crlf

# %%
BN_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8997 entries, 0 to 8996
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   filename                    8997 non-null   object
#  1   line_no                     8997 non-null   int64
#  2   head$RecordSpec             8997 non-null   object
#  3   head$DataKubun              8997 non-null   int64
#  4   head$MakeDate$Year          8997 non-null   int64
#  5   head$MakeDate$Month         8997 non-null   int64
#  6   head$MakeDate$Day           8997 non-null   int64
#  7   BanusiCode                  8997 non-null   int64
#  8   BanusiName_Co               8997 non-null   object
#  9   BanusiName                  8997 non-null   object
#  10  BanusiNameKana              8997 non-null   object
#  11  BanusiNameEng               8997 non-null   object
#  12  Fukusyoku                   8997 non-null   object
# ...
